# %% [markdown]
# ### Load data from csv using pandas

# %%
import pandas as pd

# %%
#encounters = pd.read_csv('/data/MIMIC/mini_encounter_vectors_processed.csv') 
encounters = pd.read_csv('/data/MIMIC/encounter_vectors_processed.csv')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import roc_auc_score

def run_cross_val(train_X, train_y, test_X, test_y, roc_auc):
    print('mlp')
    mlp = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu',
                        solver='adam', batch_size=256, max_iter=20,
                        early_stopping=True, verbose=True)
    mlp_pred = mlp.fit(train_X, train_y).predict(test_X)
    roc_auc['mlp'].append(roc_auc_score(test_y, mlp_pred,
                                        average='macro',
                                        sample_weight=None))
    
    print('rf')
    rf = RandomForestClassifier(n_jobs=-1, n_estimators=5, max_features='log2',
                                random_state=123)
    rf_pred = rf.fit(train_X, train_y).predict(test_X)
    roc_auc['rf'].append(roc_auc_score(test_y, rf_pred,
                                        average='macro',
                                        sample_weight=None))
    
    print('lr via hinge SGD')
    lr = SGDClassifier(loss="hinge", penalty="l2", random_state=123)
    lr_pred = lr.fit(train_X, train_y).predict(test_X)
    roc_auc['lr'].append(roc_auc_score(test_y, lr_pred,
                                        average='macro',
                                        sample_weight=None))
    
    print('svm via log SGD')
    svm = SGDClassifier(loss="log", penalty="l2", random_state=123)
    svm_pred = svm.fit(train_X, train_y).predict(test_X)
    roc_auc['svm'].append(roc_auc_score(test_y, svm_pred,
                                        average='macro',
                                        sample_weight=None))
    
    
    return roc_auc

# %%
from sklearn.cross_validation import StratifiedKFold
import pickle as pkl

# for 1, 3, 5, 10, 20, 30 Encounters
# for i in [1, 3, 5, 10, 20, 30]:
all_scores = {}
for i in [1, 3, 5, 10, 20, 30, 50]:
    print(i)
    
    encounters['6MONTH'] = 0
    encounters['1YEAR'] = 0
    encounters.loc[(encounters['SURVIVAL'] > 0) & (encounters['SURVIVAL'] < 183), '6MONTH'] = 1
    encounters.loc[(encounters['SURVIVAL'] > 0) & (encounters['SURVIVAL'] < 366), '1YEAR'] = 1
    print('Survival :', encounters['6MONTH'].sum(), encounters['1YEAR'].sum())

    y_1year = encounters['1YEAR'].values
    
    encounters_grouped = (encounters.groupby('HADM_ID').head(i).groupby('HADM_ID',
                          as_index=False).mean().drop(['SUBJECT_ID', 'HADM_ID', 'ENCOUNTER_ID',
                                                       'SURVIVAL', '6MONTH'], axis=1))    
    
    # do 1 year survival after grouping
    y_1year = encounters_grouped['1YEAR'].values
    encounters_grouped.drop(['1YEAR'], axis=1, inplace=True)
    e = encounters_grouped.values
    
    print(type(e), e.shape)
    
    cv = StratifiedKFold(y_1year, n_folds=5, random_state=123)
    roc_auc = {'svm':[], 'lr': [], 'mlp':[], 'rf':[]}
    
    for j, (train, test) in enumerate(cv):
        roc_auc = run_cross_val(e[train], y_1year[train],
                                e[test], y_1year[test],
                                roc_auc)
        print('Cross fold: ', j, roc_auc)
        
    all_scores[i] = roc_auc
pkl.dump(all_scores, open('/data/MIMIC/encounter_scores_mlp_svm_lr_rf.p', 'wb'))
# Out:
# 1
# ('Survival :', 344049L, 411879L)
# (<type 'numpy.ndarray'>, (58438, 1196))
# mlp
# Iteration 1, loss = 7.69646541
# Validation score: 0.775615
# Iteration 2, loss = 7.45237615
# Validation score: 0.779251
# Iteration 3, loss = 7.29281908
# Validation score: 0.403422
# Iteration 4, loss = 6.93997604
# Validation score: 0.785241
# Iteration 5, loss = 6.92599588
# Validation score: 0.695187
# Iteration 6, loss = 6.81351608
# Validation score: 0.644064
# Iteration 7, loss = 6.96382583
# Validation score: 0.787594
# Iteration 8, loss = 6.92453485
# Validation score: 0.786096
# Iteration 9, loss = 6.93762674
# Validation score: 0.787807
# Iteration 10, loss = 6.93649341
# Validation score: 0.778610
# Iteration 11, loss = 6.78405246
# Validation score: 0.787166
# Iteration 12, loss = 6.89997719
# Validation score: 0.780107
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 0, {'mlp': [0.54416107743459141], 'svm': [0.50752947213691357], 'lr': [0.50528071125808216], 'rf': [0.7003064049704476]})
# mlp
# Iteration 1, loss = 7.49136790
# Validation score: 0.260963
# Iteration 2, loss = 7.35007322
# Validation score: 0.766203
# Iteration 3, loss = 6.92885634
# Validation score: 0.771337
# Iteration 4, loss = 7.01600391
# Validation score: 0.769840
# Iteration 5, loss = 7.11173285
# Validation score: 0.768770
# Iteration 6, loss = 7.26726883
# Validation score: 0.786738
# Iteration 7, loss = 6.80177269
# Validation score: 0.786952
# Iteration 8, loss = 6.75690120
# Validation score: 0.780963
# Iteration 9, loss = 6.75843012
# Validation score: 0.784813
# Iteration 10, loss = 6.99342317
# Validation score: 0.777540
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 1, {'mlp': [0.54416107743459141, 0.5169195989971056], 'svm': [0.50752947213691357, 0.5], 'lr': [0.50528071125808216, 0.5], 'rf': [0.7003064049704476, 0.66589665157452393]})
# mlp
# Iteration 1, loss = 7.70708566
# Validation score: 0.769198
# Iteration 2, loss = 7.16715900
# Validation score: 0.709733
# Iteration 3, loss = 6.87595377
# Validation score: 0.771979
# Iteration 4, loss = 6.62370044
# Validation score: 0.774332
# Iteration 5, loss = 6.78954000
# Validation score: 0.406203
# Iteration 6, loss = 6.64209198
# Validation score: 0.621604
# Iteration 7, loss = 6.66066949
# Validation score: 0.395080
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 2, {'mlp': [0.54416107743459141, 0.5169195989971056, 0.50207918114344807], 'svm': [0.50752947213691357, 0.5, 0.50061018498613519], 'lr': [0.50528071125808216, 0.5, 0.49994509717799496], 'rf': [0.7003064049704476, 0.66589665157452393, 0.66558912344677235]})
# mlp
# Iteration 1, loss = 7.34390279
# Validation score: 0.772455
# Iteration 2, loss = 6.52975149
# Validation score: 0.771172
# Iteration 3, loss = 6.72336345
# Validation score: 0.660821
# Iteration 4, loss = 6.78634967
# Validation score: 0.754277
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 3, {'mlp': [0.54416107743459141, 0.5169195989971056, 0.50207918114344807, 0.50105298505366436], 'svm': [0.50752947213691357, 0.5, 0.50061018498613519, 0.5], 'lr': [0.50528071125808216, 0.5, 0.49994509717799496, 0.5], 'rf': [0.7003064049704476, 0.66589665157452393, 0.66558912344677235, 0.68479268439048924]})
# mlp
# Iteration 1, loss = 7.27103125
# Validation score: 0.773311
# Iteration 2, loss = 7.05442737
# Validation score: 0.684773
# Iteration 3, loss = 6.67284961
# Validation score: 0.772027
# Iteration 4, loss = 7.01176896
# Validation score: 0.772027
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 4, {'mlp': [0.54416107743459141, 0.5169195989971056, 0.50207918114344807, 0.50105298505366436, 0.49994509717799496], 'svm': [0.50752947213691357, 0.5, 0.50061018498613519, 0.5, 0.5], 'lr': [0.50528071125808216, 0.5, 0.49994509717799496, 0.5, 0.49994509717799496], 'rf': [0.7003064049704476, 0.66589665157452393, 0.66558912344677235, 0.68479268439048924, 0.56741232359808413]})
# 3
# ('Survival :', 344049L, 411879L)
# (<type 'numpy.ndarray'>, (58438, 1196))
# mlp
# Iteration 1, loss = 7.21541038
# Validation score: 0.770053
# Iteration 2, loss = 7.01363263
# Validation score: 0.771765
# Iteration 3, loss = 6.87674966
# Validation score: 0.771551
# Iteration 4, loss = 6.74435392
# Validation score: 0.737112
# Iteration 5, loss = 6.75434269
# Validation score: 0.773048
# Iteration 6, loss = 6.76902142
# Validation score: 0.494973
# Iteration 7, loss = 6.58040647
# Validation score: 0.773262
# Iteration 8, loss = 6.51462742
# Validation score: 0.770909
# Iteration 9, loss = 6.53244687
# Validation score: 0.692834
# Iteration 10, loss = 6.59901225
# Validation score: 0.595080
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 0, {'mlp': [0.50897868540989311], 'svm': [0.51171495612007356], 'lr': [0.51253449932944539], 'rf': [0.73341659304101092]})
# mlp
# Iteration 1, loss = 7.41059356
# Validation score: 0.780535
# Iteration 2, loss = 6.89476804
# Validation score: 0.779679
# Iteration 3, loss = 6.71000149
# Validation score: 0.768342
# Iteration 4, loss = 6.64958033
# Validation score: 0.779037
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 1, {'mlp': [0.50897868540989311, 0.50790338992273487], 'svm': [0.51171495612007356, 0.50019372336303758], 'lr': [0.51253449932944539, 0.5], 'rf': [0.73341659304101092, 0.64545614587635136]})
# mlp
# Iteration 1, loss = 7.34160612
# Validation score: 0.788235
# Iteration 2, loss = 6.84841206
# Validation score: 0.757005
# Iteration 3, loss = 7.02078769
# Validation score: 0.784171
# Iteration 4, loss = 6.29643844
# Validation score: 0.708449
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 2, {'mlp': [0.50897868540989311, 0.50790338992273487, 0.50307681285565853], 'svm': [0.51171495612007356, 0.50019372336303758, 0.50396463892385879], 'lr': [0.51253449932944539, 0.5, 0.50033254390407012], 'rf': [0.73341659304101092, 0.64545614587635136, 0.64476742496660422]})
# mlp
# Iteration 1, loss = 7.76738918
# Validation score: 0.769675
# Iteration 2, loss = 7.42452901
# Validation score: 0.772669
# Iteration 3, loss = 6.84617562
# Validation score: 0.760051
# Iteration 4, loss = 6.95381566
# Validation score: 0.756416
# Iteration 5, loss = 6.65532817
# Validation score: 0.764756
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 3, {'mlp': [0.50897868540989311, 0.50790338992273487, 0.50307681285565853, 0.50038759689922485], 'svm': [0.51171495612007356, 0.50019372336303758, 0.50396463892385879, 0.50041668688282204], 'lr': [0.51253449932944539, 0.5, 0.50033254390407012, 0.5], 'rf': [0.73341659304101092, 0.64545614587635136, 0.64476742496660422, 0.65263403736626491]})
# mlp
# Iteration 1, loss = 7.72027033
# Validation score: 0.778015
# Iteration 2, loss = 7.04757220
# Validation score: 0.781437
# Iteration 3, loss = 7.32100052
# Validation score: 0.776946
# Iteration 4, loss = 6.87243486
# Validation score: 0.780368
# Iteration 5, loss = 6.97580850
# Validation score: 0.780154
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 4, {'mlp': [0.50897868540989311, 0.50790338992273487, 0.50307681285565853, 0.50038759689922485, 0.50471261990308158], 'svm': [0.51171495612007356, 0.50019372336303758, 0.50396463892385879, 0.50041668688282204, 0.5], 'lr': [0.51253449932944539, 0.5, 0.50033254390407012, 0.5, 0.5], 'rf': [0.73341659304101092, 0.64545614587635136, 0.64476742496660422, 0.65263403736626491, 0.64360294874970536]})
# 5
# ('Survival :', 344049L, 411879L)
# (<type 'numpy.ndarray'>, (58438, 1196))
# mlp
# Iteration 1, loss = 7.77192438
# Validation score: 0.782460
# Iteration 2, loss = 7.40961916
# Validation score: 0.784385
# Iteration 3, loss = 6.78958720
# Validation score: 0.782674
# Iteration 4, loss = 6.72055405
# Validation score: 0.647273
# Iteration 5, loss = 6.58359417
# Validation score: 0.757005
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 0, {'mlp': [0.60849942057420825], 'svm': [0.51927242210191482], 'lr': [0.51425837561588061], 'rf': [0.71282701373702217]})
# mlp
# Iteration 1, loss = 7.73248484
# Validation score: 0.785455
# Iteration 2, loss = 7.37114108
# Validation score: 0.784171
# Iteration 3, loss = 7.07751648
# Validation score: 0.404278
# Iteration 4, loss = 6.67701875
# Validation score: 0.782888
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 1, {'mlp': [0.60849942057420825, 0.50296700721164844], 'svm': [0.51927242210191482, 0.50038744672607516], 'lr': [0.51425837561588061, 0.50038744672607516], 'rf': [0.71282701373702217, 0.64915026981088886]})
# mlp
# Iteration 1, loss = 7.00955807
# Validation score: 0.776898
# Iteration 2, loss = 6.56413542
# Validation score: 0.778610
# Iteration 3, loss = 6.47678820
# Validation score: 0.777112
# Iteration 4, loss = 6.65553023
# Validation score: 0.778610
# Iteration 5, loss = 6.44682422
# Validation score: 0.779893
# Iteration 6, loss = 6.49061857
# Validation score: 0.720000
# Iteration 7, loss = 6.46441435
# Validation score: 0.632086
# Iteration 8, loss = 6.39337301
# Validation score: 0.776471
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 2, {'mlp': [0.60849942057420825, 0.50296700721164844, 0.53446450731449813], 'svm': [0.51927242210191482, 0.50038744672607516, 0.50732847377770174], 'lr': [0.51425837561588061, 0.50038744672607516, 0.50116546715026522], 'rf': [0.71282701373702217, 0.64915026981088886, 0.65120043605731459]})
# mlp
# Iteration 1, loss = 6.89454324
# Validation score: 0.764115
# Iteration 2, loss = 6.64475515
# Validation score: 0.787211
# Iteration 3, loss = 6.61483179
# Validation score: 0.785073
# Iteration 4, loss = 6.59426282
# Validation score: 0.787639
# Iteration 5, loss = 6.37253559
# Validation score: 0.782506
# Iteration 6, loss = 6.70038800
# Validation score: 0.754491
# Iteration 7, loss = 6.38223609
# Validation score: 0.333191
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 3, {'mlp': [0.60849942057420825, 0.50296700721164844, 0.53446450731449813, 0.50360473202741229], 'svm': [0.51927242210191482, 0.50038744672607516, 0.50732847377770174, 0.5], 'lr': [0.51425837561588061, 0.50038744672607516, 0.50116546715026522, 0.5], 'rf': [0.71282701373702217, 0.64915026981088886, 0.65120043605731459, 0.64967543494526314]})
# mlp
# Iteration 1, loss = 6.97355473
# Validation score: 0.782720
# Iteration 2, loss = 6.50476911
# Validation score: 0.785073
# Iteration 3, loss = 6.43013104
# Validation score: 0.785287
# Iteration 4, loss = 6.46811376
# Validation score: 0.664671
# Iteration 5, loss = 6.55934268
# Validation score: 0.651198
# Iteration 6, loss = 6.26384375
# Validation score: 0.688195
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 4, {'mlp': [0.60849942057420825, 0.50296700721164844, 0.53446450731449813, 0.50360473202741229, 0.50621138182316516], 'svm': [0.51927242210191482, 0.50038744672607516, 0.50732847377770174, 0.5, 0.5], 'lr': [0.51425837561588061, 0.50038744672607516, 0.50116546715026522, 0.5, 0.5], 'rf': [0.71282701373702217, 0.64915026981088886, 0.65120043605731459, 0.64967543494526314, 0.62523182610190831]})
# 10
# ('Survival :', 344049L, 411879L)
# (<type 'numpy.ndarray'>, (58438, 1196))
# mlp
# Iteration 1, loss = 7.30264276
# Validation score: 0.774545
# Iteration 2, loss = 6.87703853
# Validation score: 0.774332
# Iteration 3, loss = 6.55040229
# Validation score: 0.777112
# Iteration 4, loss = 6.47900949
# Validation score: 0.774118
# Iteration 5, loss = 6.41633676
# Validation score: 0.271230
# Iteration 6, loss = 6.56572317
# Validation score: 0.782246
# Iteration 7, loss = 6.23600261
# Validation score: 0.321925
# Iteration 8, loss = 6.52801202
# Validation score: 0.782888
# Iteration 9, loss = 6.44693452
# Validation score: 0.777968
# Iteration 10, loss = 6.31095901
# Validation score: 0.775829
# Iteration 11, loss = 6.55138988
# Validation score: 0.294118
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 0, {'mlp': [0.63304719341070836], 'svm': [0.51507391970454841], 'lr': [0.51009514205961615], 'rf': [0.69215162351324711]})
# mlp
# Iteration 1, loss = 7.69750911
# Validation score: 0.261604
# Iteration 2, loss = 7.30932530
# Validation score: 0.751016
# Iteration 3, loss = 6.97911368
# Validation score: 0.785668
# Iteration 4, loss = 6.92437238
# Validation score: 0.784385
# Iteration 5, loss = 6.78746655
# Validation score: 0.784813
# Iteration 6, loss = 6.54988808
# Validation score: 0.777540
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 1, {'mlp': [0.63304719341070836, 0.52796582981095175], 'svm': [0.51507391970454841, 0.50058117008911274], 'lr': [0.51009514205961615, 0.50058117008911274], 'rf': [0.69215162351324711, 0.6421503408165532]})
# mlp
# Iteration 1, loss = 7.17996421
# Validation score: 0.790588
# Iteration 2, loss = 6.62325130
# Validation score: 0.787380
# Iteration 3, loss = 6.59781571
# Validation score: 0.791230
# Iteration 4, loss = 6.53443158
# Validation score: 0.789091
# Iteration 5, loss = 6.40837214
# Validation score: 0.790588
# Iteration 6, loss = 6.35269980
# Validation score: 0.788021
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 2, {'mlp': [0.63304719341070836, 0.52796582981095175, 0.51036063687613875], 'svm': [0.51507391970454841, 0.50058117008911274, 0.50141409333530784], 'lr': [0.51009514205961615, 0.50058117008911274, 0.50141409333530784], 'rf': [0.69215162351324711, 0.6421503408165532, 0.63123754874832405]})
# mlp
# Iteration 1, loss = 7.12942864
# Validation score: 0.783790
# Iteration 2, loss = 6.67002674
# Validation score: 0.693755
# Iteration 3, loss = 6.61662752
# Validation score: 0.784859
# Iteration 4, loss = 6.83949961
# Validation score: 0.791061
# Iteration 5, loss = 6.32476571
# Validation score: 0.776946
# Iteration 6, loss = 6.36118526
# Validation score: 0.777588
# Iteration 7, loss = 6.39467390
# Validation score: 0.648417
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 3, {'mlp': [0.63304719341070836, 0.52796582981095175, 0.51036063687613875, 0.51469671936486383], 'svm': [0.51507391970454841, 0.50058117008911274, 0.50141409333530784, 0.50416359168303104], 'lr': [0.51009514205961615, 0.50058117008911274, 0.50141409333530784, 0.50712259842714058], 'rf': [0.69215162351324711, 0.6421503408165532, 0.63123754874832405, 0.640495619265528]})
# mlp
# Iteration 1, loss = 7.26259764
# Validation score: 0.770103
# Iteration 2, loss = 7.07943808
# Validation score: 0.742729
# Iteration 3, loss = 7.07274424
# Validation score: 0.766681
# Iteration 4, loss = 6.07657259
# Validation score: 0.781009
# Iteration 5, loss = 6.50757473
# Validation score: 0.694397
# Iteration 6, loss = 6.12815983
# Validation score: 0.781865
# Iteration 7, loss = 6.40552861
# Validation score: 0.679213
# Iteration 8, loss = 6.14766537
# Validation score: 0.782293
# Iteration 9, loss = 6.23917634
# Validation score: 0.786570
# Iteration 10, loss = 6.03434248
# Validation score: 0.779726
# Iteration 11, loss = 6.26113195
# Validation score: 0.786570
# Iteration 12, loss = 6.17366128
# Validation score: 0.785073
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 4, {'mlp': [0.63304719341070836, 0.52796582981095175, 0.51036063687613875, 0.51469671936486383, 0.50551362653993914], 'svm': [0.51507391970454841, 0.50058117008911274, 0.50141409333530784, 0.50416359168303104, 0.5], 'lr': [0.51009514205961615, 0.50058117008911274, 0.50141409333530784, 0.50712259842714058, 0.50038759689922485], 'rf': [0.69215162351324711, 0.6421503408165532, 0.63123754874832405, 0.640495619265528, 0.62622950401045963]})
# 20
# ('Survival :', 344049L, 411879L)
# (<type 'numpy.ndarray'>, (58438, 1196))
# mlp
# Iteration 1, loss = 7.66678462
# Validation score: 0.590802
# Iteration 2, loss = 7.11369052
# Validation score: 0.763209
# Iteration 3, loss = 6.59504439
# Validation score: 0.789519
# Iteration 4, loss = 6.54078661
# Validation score: 0.789733
# Iteration 5, loss = 6.34906382
# Validation score: 0.790802
# Iteration 6, loss = 6.39539451
# Validation score: 0.789519
# Iteration 7, loss = 6.55985960
# Validation score: 0.754011
# Iteration 8, loss = 6.41483993
# Validation score: 0.803209
# Iteration 9, loss = 6.40055377
# Validation score: 0.801711
# Iteration 10, loss = 6.46196520
# Validation score: 0.513369
# Iteration 11, loss = 6.33287569
# Validation score: 0.656257
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 0, {'mlp': [0.53947680950320409], 'svm': [0.52377896315308037], 'lr': [0.51439406918487329], 'rf': [0.66090151582415901]})
# mlp
# Iteration 1, loss = 7.73815556
# Validation score: 0.784385
# Iteration 2, loss = 7.16856643
# Validation score: 0.784171
# Iteration 3, loss = 6.69719907
# Validation score: 0.795508
# Iteration 4, loss = 6.64785295
# Validation score: 0.786096
# Iteration 5, loss = 6.44405806
# Validation score: 0.787807
# Iteration 6, loss = 6.49054641
# Validation score: 0.784599
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 1, {'mlp': [0.53947680950320409, 0.67098691534503885], 'svm': [0.52377896315308037, 0.50091371399318285], 'lr': [0.51439406918487329, 0.50071999063014527], 'rf': [0.66090151582415901, 0.646095345759509]})
# mlp
# Iteration 1, loss = 7.18249448
# Validation score: 0.782032
# Iteration 2, loss = 6.75900296
# Validation score: 0.781604
# Iteration 3, loss = 6.56847849
# Validation score: 0.787166
# Iteration 4, loss = 6.51543581
# Validation score: 0.703529
# Iteration 5, loss = 6.40818303
# Validation score: 0.471016
# Iteration 6, loss = 6.23813041
# Validation score: 0.510802
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 2, {'mlp': [0.53947680950320409, 0.67098691534503885, 0.52354946042289341], 'svm': [0.52377896315308037, 0.50091371399318285, 0.5018854577804106], 'lr': [0.51439406918487329, 0.50071999063014527, 0.50519126284020865], 'rf': [0.66090151582415901, 0.646095345759509, 0.64337071078882357]})
# mlp
# Iteration 1, loss = 7.44518260
# Validation score: 0.603721
# Iteration 2, loss = 6.78401865
# Validation score: 0.577417
# Iteration 3, loss = 6.60409495
# Validation score: 0.787211
# Iteration 4, loss = 6.46427961
# Validation score: 0.770103
# Iteration 5, loss = 6.25783359
# Validation score: 0.792344
# Iteration 6, loss = 6.71381046
# Validation score: 0.786997
# Iteration 7, loss = 6.15765817
# Validation score: 0.475834
# Iteration 8, loss = 6.01932049
# Validation score: 0.664671
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 3, {'mlp': [0.53947680950320409, 0.67098691534503885, 0.52354946042289341, 0.51100144024147032], 'svm': [0.52377896315308037, 0.50091371399318285, 0.5018854577804106, 0.50972597107770412], 'lr': [0.51439406918487329, 0.50071999063014527, 0.50519126284020865, 0.5], 'rf': [0.66090151582415901, 0.646095345759509, 0.64337071078882357, 0.64102538893754957]})
# mlp
# Iteration 1, loss = 6.81837772
# Validation score: 0.781865
# Iteration 2, loss = 6.67130319
# Validation score: 0.741873
# Iteration 3, loss = 6.20669273
# Validation score: 0.668734
# Iteration 4, loss = 6.37234109
# Validation score: 0.785500
# Iteration 5, loss = 6.12378652
# Validation score: 0.575278
# Iteration 6, loss = 6.31394807
# Validation score: 0.786784
# Iteration 7, loss = 6.36688996
# Validation score: 0.787639
# Iteration 8, loss = 6.27509197
# Validation score: 0.777588
# Iteration 9, loss = 5.96114097
# Validation score: 0.788067
# Iteration 10, loss = 6.07356919
# Validation score: 0.788494
# Iteration 11, loss = 5.87078483
# Validation score: 0.574209
# Iteration 12, loss = 6.21264344
# Validation score: 0.789991
# Iteration 13, loss = 6.06331970
# Validation score: 0.788067
# Iteration 14, loss = 6.20298603
# Validation score: 0.786997
# Iteration 15, loss = 5.80715147
# Validation score: 0.552609
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 4, {'mlp': [0.53947680950320409, 0.67098691534503885, 0.52354946042289341, 0.51100144024147032, 0.56015289371920229], 'svm': [0.52377896315308037, 0.50091371399318285, 0.5018854577804106, 0.50972597107770412, 0.50052649252683212], 'lr': [0.51439406918487329, 0.50071999063014527, 0.50519126284020865, 0.5, 0.50052649252683212], 'rf': [0.66090151582415901, 0.646095345759509, 0.64337071078882357, 0.64102538893754957, 0.68373193207712279]})
# 30
# ('Survival :', 344049L, 411879L)
# (<type 'numpy.ndarray'>, (58438, 1196))
# mlp
# Iteration 1, loss = 7.17339977
# Validation score: 0.781176
# Iteration 2, loss = 6.94496441
# Validation score: 0.783316
# Iteration 3, loss = 6.94485553
# Validation score: 0.764278
# Iteration 4, loss = 6.35355254
# Validation score: 0.790160
# Iteration 5, loss = 6.45403114
# Validation score: 0.793583
# Iteration 6, loss = 6.22500874
# Validation score: 0.791444
# Iteration 7, loss = 6.38983196
# Validation score: 0.780535
# Iteration 8, loss = 6.40337483
# Validation score: 0.669947
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 0, {'mlp': [0.63022066594974624], 'svm': [0.51198547110939485], 'lr': [0.51579631406149973], 'rf': [0.66230710039201157]})
# mlp
# Iteration 1, loss = 7.74109395
# Validation score: 0.770909
# Iteration 2, loss = 6.80145326
# Validation score: 0.783316
# Iteration 3, loss = 6.35803641
# Validation score: 0.547594
# Iteration 4, loss = 6.40278114
# Validation score: 0.780963
# Iteration 5, loss = 6.34885203
# Validation score: 0.775829
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 1, {'mlp': [0.63022066594974624, 0.62004173380261463], 'svm': [0.51198547110939485, 0.50091371399318285], 'lr': [0.51579631406149973, 0.50091371399318285], 'rf': [0.66230710039201157, 0.63267665785995053]})
# mlp
# Iteration 1, loss = 6.93905100
# Validation score: 0.581390
# Iteration 2, loss = 6.38792518
# Validation score: 0.703529
# Iteration 3, loss = 6.48358958
# Validation score: 0.791444
# Iteration 4, loss = 6.42878573
# Validation score: 0.786310
# Iteration 5, loss = 6.25625020
# Validation score: 0.346096
# Iteration 6, loss = 6.13776308
# Validation score: 0.617968
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 2, {'mlp': [0.63022066594974624, 0.62004173380261463, 0.53989901454433398], 'svm': [0.51198547110939485, 0.50091371399318285, 0.51248446777680845], 'lr': [0.51579631406149973, 0.50091371399318285, 0.5019693754994381], 'rf': [0.66230710039201157, 0.63267665785995053, 0.64768127365357575]})
# mlp
# Iteration 1, loss = 7.15031941
# Validation score: 0.783790
# Iteration 2, loss = 6.82132733
# Validation score: 0.536142
# Iteration 3, loss = 6.37667811
# Validation score: 0.795766
# Iteration 4, loss = 6.38794455
# Validation score: 0.798332
# Iteration 5, loss = 6.35408046
# Validation score: 0.789778
# Iteration 6, loss = 6.09120126
# Validation score: 0.792130
# Iteration 7, loss = 6.21121375
# Validation score: 0.788708
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 3, {'mlp': [0.63022066594974624, 0.62004173380261463, 0.53989901454433398, 0.54524311735669717], 'svm': [0.51198547110939485, 0.50091371399318285, 0.51248446777680845, 0.5], 'lr': [0.51579631406149973, 0.50091371399318285, 0.5019693754994381, 0.5], 'rf': [0.66230710039201157, 0.63267665785995053, 0.64768127365357575, 0.67854116817883514]})
# mlp
# Iteration 1, loss = 7.23389108
# Validation score: 0.777802
# Iteration 2, loss = 6.68378311
# Validation score: 0.763045
# Iteration 3, loss = 6.44071406
# Validation score: 0.522027
# Iteration 4, loss = 6.22725255
# Validation score: 0.781009
# Iteration 5, loss = 6.20279141
# Validation score: 0.770530
# Iteration 6, loss = 6.06132904
# Validation score: 0.781651
# Iteration 7, loss = 6.26855975
# Validation score: 0.697177
# Iteration 8, loss = 6.10147551
# Validation score: 0.523311
# Iteration 9, loss = 6.00053313
# Validation score: 0.647562
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 4, {'mlp': [0.63022066594974624, 0.62004173380261463, 0.53989901454433398, 0.54524311735669717, 0.50326876080500305], 'svm': [0.51198547110939485, 0.50091371399318285, 0.51248446777680845, 0.5, 0.5], 'lr': [0.51579631406149973, 0.50091371399318285, 0.5019693754994381, 0.5, 0.5], 'rf': [0.66230710039201157, 0.63267665785995053, 0.64768127365357575, 0.67854116817883514, 0.6620400186243991]})
# 50
# ('Survival :', 344049L, 411879L)
# (<type 'numpy.ndarray'>, (58438, 1196))
# mlp
# Iteration 1, loss = 7.60647598
# Validation score: 0.784599
# Iteration 2, loss = 7.25459702
# Validation score: 0.787166
# Iteration 3, loss = 7.24567847
# Validation score: 0.275080
# Iteration 4, loss = 7.04826951
# Validation score: 0.788449
# Iteration 5, loss = 6.41833867
# Validation score: 0.787594
# Iteration 6, loss = 6.21161569
# Validation score: 0.797005
# Iteration 7, loss = 6.74398741
# Validation score: 0.792299
# Iteration 8, loss = 5.96396514
# Validation score: 0.789519
# Iteration 9, loss = 6.06225374
# Validation score: 0.791872
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 0, {'mlp': [0.59715300044454045], 'svm': [0.51491946430331681], 'lr': [0.5116873238977625], 'rf': [0.66022479227652375]})
# mlp
# Iteration 1, loss = 7.05827539
# Validation score: 0.776898
# Iteration 2, loss = 6.68564412
# Validation score: 0.785455
# Iteration 3, loss = 6.39369356
# Validation score: 0.333476
# Iteration 4, loss = 6.26948629
# Validation score: 0.780963
# Iteration 5, loss = 6.19588695
# Validation score: 0.741604
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 1, {'mlp': [0.59715300044454045, 0.507919896931598], 'svm': [0.51491946430331681, 0.50091371399318285], 'lr': [0.5116873238977625, 0.50091371399318285], 'rf': [0.66022479227652375, 0.65218868685340547]})
# mlp
# Iteration 1, loss = 7.24619302
# Validation score: 0.770481
# Iteration 2, loss = 6.77266897
# Validation score: 0.668877
# Iteration 3, loss = 6.73831601
# Validation score: 0.787166
# Iteration 4, loss = 6.54971783
# Validation score: 0.632086
# Iteration 5, loss = 6.60284499
# Validation score: 0.784813
# Iteration 6, loss = 6.11802407
# Validation score: 0.786952
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 2, {'mlp': [0.59715300044454045, 0.507919896931598, 0.6236555775162117], 'svm': [0.51491946430331681, 0.50091371399318285, 0.50329955111571856], 'lr': [0.5116873238977625, 0.50091371399318285, 0.5], 'rf': [0.66022479227652375, 0.65218868685340547, 0.63885704364491436]})
# mlp
# Iteration 1, loss = 7.08303591
# Validation score: 0.776518
# Iteration 2, loss = 6.76210991
# Validation score: 0.774594
# Iteration 3, loss = 6.41214754
# Validation score: 0.785714
# Iteration 4, loss = 6.13926686
# Validation score: 0.769889
# Iteration 5, loss = 6.13447179
# Validation score: 0.783362
# Iteration 6, loss = 6.12519170
# Validation score: 0.779726
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 3, {'mlp': [0.59715300044454045, 0.507919896931598, 0.6236555775162117, 0.5474912602368226], 'svm': [0.51491946430331681, 0.50091371399318285, 0.50329955111571856, 0.5], 'lr': [0.5116873238977625, 0.50091371399318285, 0.5, 0.5], 'rf': [0.66022479227652375, 0.65218868685340547, 0.63885704364491436, 0.65455891328163096]})
# mlp
# Iteration 1, loss = 7.28487071
# Validation score: 0.249358
# Iteration 2, loss = 6.61154872
# Validation score: 0.785928
# Iteration 3, loss = 6.51595626
# Validation score: 0.791488
# Iteration 4, loss = 6.21054152
# Validation score: 0.786142
# Iteration 5, loss = 6.47402020
# Validation score: 0.800470
# Iteration 6, loss = 6.15532528
# Validation score: 0.793413
# Iteration 7, loss = 6.06309545
# Validation score: 0.272027
# Iteration 8, loss = 6.29600914
# Validation score: 0.794696
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# rf
# lr via hinge SGD
# svm via log SGD
# ('Cross fold: ', 4, {'mlp': [0.59715300044454045, 0.507919896931598, 0.6236555775162117, 0.5474912602368226, 0.51537481177695321], 'svm': [0.51491946430331681, 0.50091371399318285, 0.50329955111571856, 0.5, 0.50052649252683212], 'lr': [0.5116873238977625, 0.50091371399318285, 0.5, 0.5, 0.5], 'rf': [0.66022479227652375, 0.65218868685340547, 0.63885704364491436, 0.65455891328163096, 0.66160694601562986]})
